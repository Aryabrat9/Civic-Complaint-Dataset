# %%
# properly balanced dataset with equal array lengths
expanded_data = {
    "Complaint": [
        # Fire Emergencies (25 complaints)
        "Major fire in apartment building with people trapped on upper floors!",
        "Factory fire with chemical explosions reported in industrial area",
        "Electrical short circuit caused fire in shopping mall food court",
        "Forest fire spreading rapidly towards residential colony",
        "Car burst into flames on busy highway during peak traffic",
        "Gas cylinder explosion in restaurant kitchen, multiple injuries reported",
        "Warehouse fire with toxic smoke affecting nearby schools",
        "Residential building fire with elderly residents needing evacuation",
        "Transformer fire causing power outage in entire neighborhood",
        "Bush fire approaching petrol pump, extreme danger situation",
        "Fire in hospital ICU section, patients need immediate evacuation",
        "Underground cable fire causing road cave-in and power disruption",
        "Fireworks factory explosion with multiple casualties feared",
        "Kitchen fire spread to entire house, family trapped inside",
        "Chemical plant fire with toxic gas leakage, evacuate immediately!",
        "Hotel fire emergency with guests stranded on higher floors",
        "Library fire destroying historical documents and books",
        "Parking garage fire spreading to adjacent buildings",
        "School laboratory chemical fire with students evacuated",
        "Metro station electrical fire causing service suspension",
        "Industrial furnace explosion in manufacturing unit",
        "Restaurant chimney fire threatening adjacent structures",
        "Gas pipeline fire near residential complex",
        "Vehicle repair shop fire with fuel tanks exploding",
        "Textile factory fire with flammable materials burning",
        
        # Sanitation Issues (25 complaints)
        "Garbage not collected for 2 weeks, piles attracting rats and diseases",
        "Sewage line burst flooding entire street with waste water",
        "Overflowing garbage bins near hospital creating health hazard",
        "Drainage blockage causing mosquito breeding and dengue outbreak",
        "Illegal garbage dumping in park area creating foul smell",
        "Medical waste mixed with regular garbage near residential area",
        "Dead animal carcass rotting on roadside for 3 days",
        "Sewage treatment plant malfunction contaminating river water",
        "Public toilets blocked and extremely dirty, unusable condition",
        "Garbage truck leaking waste fluid all over the road",
        "Construction debris dumped illegally blocking pedestrian path",
        "Food waste from restaurants attracting stray animals at night",
        "Drain cleaning delayed causing water logging during rains",
        "Biomedical waste disposal violation by private clinic",
        "Plastic waste burning creating toxic air pollution",
        "Sanitation workers strike, garbage accumulating everywhere",
        "Drainage water mixing with drinking water supply lines",
        "Public market area filled with vegetable waste and rotten food",
        "Sewage water entering playground, children at health risk",
        "Garbage processing plant breakdown, waste piling up",
        "Industrial waste being dumped in residential area drains",
        "Septic tank overflow in apartment complex courtyard",
        "Animal slaughter waste disposed in open area",
        "Mobile toilet units not serviced for festival crowd",
        "Garbage chute blockage in high-rise building",
        
        # Road Infrastructure (25 complaints)
        "Major pothole on highway causing multiple vehicle accidents",
        "Bridge collapse incident with vehicles fallen into river",
        "Road cave-in after heavy rains, cars stuck in crater",
        "Tree fell on main road during storm blocking all traffic",
        "Landslide on mountain road trapping several vehicles",
        "Road construction without safety measures causing accidents",
        "Open manhole near school, child almost fell into it",
        "Speed breaker damaged causing vehicle underside damage",
        "Road divider broken creating traffic chaos at intersection",
        "Footpath collapsed near market area, pedestrian injury reported",
        "Flyover construction debris falling on moving vehicles",
        "Water logging on highway causing complete traffic standstill",
        "Oil spill on road causing multiple bike skidding accidents",
        "Road sinking near metro construction site, buildings at risk",
        "Illegal road digging by telecom company creating hazards",
        "Traffic signal not working causing major junction chaos",
        "Road blocked by protestors, emergency vehicles stuck",
        "Construction material spill on highway during transport",
        "Road erosion near river bank threatening nearby houses",
        "Unauthorized speed bumps causing traffic congestion",
        "Poor road markings causing confusion and near-misses",
        "Road flooding during monsoon making it impassable",
        "Cattle on highway causing multiple accident risks",
        "Road repair work delayed for months causing inconvenience",
        "Illegal parking blocking emergency vehicle access",
        
        # Electricity Issues (25 complaints)
        "Major power outage in hospital ICU during surgeries",
        "Transformer explosion causing fire in residential area",
        "Live electric wire fallen on road after storm, extreme danger",
        "Electricity pole tilted dangerously near school entrance",
        "Power fluctuation damaging household appliances in entire sector",
        "Street lights not working making area unsafe at night",
        "Electrical substation fire causing city-wide blackout",
        "Illegal electricity tapping causing frequent short circuits",
        "Smart meter malfunction causing inflated electricity bills",
        "Underground cable fault disrupting power for 48 hours",
        "Electric shock incident from faulty street light pole",
        "Power theft from main lines creating safety hazards",
        "Generator exhaust fumes affecting asthma patients nearby",
        "Voltage fluctuation damaging industrial machinery",
        "Electricity bill dispute leading to wrongful disconnection",
        "Solar panel installation damaged during storm",
        "High tension wires too low posing risk to tall vehicles",
        "Electrical maintenance work delayed for weeks",
        "Power backup system failure during critical hours",
        "Smart grid malfunction affecting entire neighborhood",
        "Street light circuit shorting during rain",
        "Electricity meter burning due to overload",
        "Distribution box overheating in residential building",
        "Power cable theft from industrial area",
        "Electrical wiring exposed in public park",
        
        # Water Supply Issues (25 complaints)
        "Major water pipeline burst flooding residential area",
        "Drinking water contamination reported in multiple areas",
        "Water supply disruption in hospital for over 24 hours",
        "Sewage mixing with drinking water causing health emergency",
        "Water tanker overflow wasting thousands of liters",
        "Borewell contamination with industrial chemicals",
        "Water treatment plant malfunction affecting entire city",
        "Illegal water connections causing low pressure issues",
        "Water leakage from overhead tank damaging building structure",
        "Groundwater depletion causing well collapse in rural area",
        "Water meter not working leading to billing disputes",
        "Water pump failure leaving apartments without supply",
        "River water pollution affecting treatment plant output",
        "Water pipeline repair work taking too long",
        "Storage tank cleaning delayed causing water quality issues",
        "Water pressure too low in high-rise buildings",
        "Water pipeline corrosion causing frequent leaks",
        "Illegal groundwater extraction by industries",
        "Water tank contamination from bird droppings",
        "Pipeline joint failure causing road collapse",
        "Water supply timing reduced without notice",
        "Water quality test results showing contamination",
        "Old lead pipes still in use in some areas",
        "Water pump house equipment theft",
        "Reservoir water level critically low",
        
        # Public Safety Issues (25 complaints)
        "Building collapse in old city area with people trapped",
        "Illegal construction blocking fire safety access",
        "Chemical factory violation causing air pollution emergency",
        "Public fight turning violent near market area",
        "Theft of public property from community park",
        "Vandalism of public buses causing service disruption",
        "Illegal street hawking creating traffic congestion",
        "Begging mafia operating at traffic signals",
        "Public drunkenness and nuisance in residential area",
        "Eve teasing complaints near college campus",
        "Illegal gambling den operating in residential building",
        "Stray dog menace causing multiple bite incidents",
        "Illegal firecracker storage creating explosion risk",
        "Building safety violations in commercial complex",
        "Public protest turning violent, police intervention needed",
        "Abandoned building becoming drug addicts den",
        "Illegal street racing on highway during nights",
        "Child labor violations in local market shops",
        "Food safety violations in street food stalls",
        "Illegal animal fighting rings in suburban areas",
        "Public monument vandalism and graffiti",
        "Illegal liquor brewing in residential premises",
        "Traffic rule violations causing accidents",
        "Unauthorized loudspeakers during night hours",
        "Illegal tree cutting in protected forest area"
    ],
    
    "Category": [
        # Fire (25)
        "fire", "fire", "fire", "fire", "fire", "fire", "fire", "fire", "fire", 
        "fire", "fire", "fire", "fire", "fire", "fire", "fire", "fire", "fire",
        "fire", "fire", "fire", "fire", "fire", "fire", "fire",
        
        # Sanitation (25)
        "sanitation", "sanitation", "sanitation", "sanitation", "sanitation",
        "sanitation", "sanitation", "sanitation", "sanitation", "sanitation",
        "sanitation", "sanitation", "sanitation", "sanitation", "sanitation",
        "sanitation", "sanitation", "sanitation", "sanitation", "sanitation",
        "sanitation", "sanitation", "sanitation", "sanitation", "sanitation",
        
        # Roads (25)
        "roads", "roads", "roads", "roads", "roads", "roads", "roads", "roads",
        "roads", "roads", "roads", "roads", "roads", "roads", "roads", "roads",
        "roads", "roads", "roads", "roads", "roads", "roads", "roads", "roads",
        "roads",
        
        # Electricity (25)
        "electricity", "electricity", "electricity", "electricity", "electricity",
        "electricity", "electricity", "electricity", "electricity", "electricity",
        "electricity", "electricity", "electricity", "electricity", "electricity",
        "electricity", "electricity", "electricity", "electricity", "electricity",
        "electricity", "electricity", "electricity", "electricity", "electricity",
        
        # Water (25)
        "water", "water", "water", "water", "water", "water", "water", "water",
        "water", "water", "water", "water", "water", "water", "water", "water",
        "water", "water", "water", "water", "water", "water", "water", "water",
        "water",
        
        # Public Safety (25)
        "public_safety", "public_safety", "public_safety", "public_safety", "public_safety",
        "public_safety", "public_safety", "public_safety", "public_safety", "public_safety",
        "public_safety", "public_safety", "public_safety", "public_safety", "public_safety",
        "public_safety", "public_safety", "public_safety", "public_safety", "public_safety",
        "public_safety", "public_safety", "public_safety", "public_safety", "public_safety"
    ],
    
    "True_Urgency": [
        # Fire (25)
        "High", "High", "High", "High", "High", "High", "High", "High", "High",
        "High", "High", "High", "High", "High", "High", "High", "High", "High",
        "High", "High", "High", "High", "High", "High", "High",
        
        # Sanitation (25)
        "Medium", "High", "High", "High", "Medium", "High", "Medium", "High",
        "Medium", "Medium", "Medium", "Low", "Medium", "High", "Medium", "High",
        "Medium", "High", "High", "Medium", "Medium", "High", "Medium", "Low",
        "Medium",
        
        # Roads (25)
        "High", "High", "High", "High", "High", "High", "High", "Medium",
        "Medium", "Medium", "High", "High", "High", "High", "Medium", "High",
        "High", "Medium", "High", "Medium", "Medium", "High", "Medium", "Medium",
        "High",
        
        # Electricity (25)
        "High", "High", "High", "High", "Medium", "Medium", "High", "Medium",
        "Low", "High", "High", "Medium", "Medium", "Medium", "Low", "Medium",
        "High", "Medium", "Medium", "Medium", "Medium", "Medium", "Medium", "Medium",
        "High",
        
        # Water (25)
        "High", "High", "High", "High", "Medium", "High", "High", "Medium",
        "Medium", "High", "Low", "Medium", "High", "Medium", "Medium", "Medium",
        "Medium", "Medium", "Medium", "High", "Low", "Medium", "High", "Medium",
        "High",
        
        # Public Safety (25)
        "High", "High", "High", "Medium", "Medium", "Medium", "Medium", "Low",
        "Low", "Medium", "Medium", "Medium", "High", "Medium", "Medium", "High",
        "High", "Medium", "Medium", "High", "Medium", "High", "Medium", "Low",
        "High"
    ]
}
